# %% [markdown]
# ## Custom pipeline notebook
# Created by Nikolay Pavlychev \
# email: nikolaypavlychev@ya.ru

# %%
from datetime import datetime

import numpy as np 
import pandas as pd 
import seaborn as sns     

import joblib

from sklearn.metrics import mean_squared_error
from math import sqrt

from sklearn.ensemble import RandomForestRegressor
import optuna

# Disable warnings
import warnings
warnings.filterwarnings("ignore")

# %%
sales = pd.read_csv('./data/sales_train.csv')
item_cat = pd.read_csv('./data/item_categories.csv')
items = pd.read_csv('./data/items.csv')
sample = pd.read_csv('./data/sample_submission.csv')
shop = pd.read_csv('./data/shops.csv')
test = pd.read_csv('./data/test.csv')

# %% [markdown]
# ## Train model based on dataset

# %%
sales_agg_features_target = pd.read_csv('./data/sales_agg_features_target.csv',sep=';')

sales_agg_features_target.head(10)
# Out:
#         ID  item_category_id  date_block_num  item_price_sum  item_price_mean  \
# 0   0_1000                67               0           290.0             58.0
# 1   0_1000                67               1           232.0             58.0
# 2  0_10004                40               1            64.0             64.0
# 3   0_1001                67               0           116.0             58.0
# 4  0_10012                40               0            76.0             76.0
# 5  0_10012                40               1           152.0             76.0
# 6   0_1002                67               0           116.0             58.0
# 7   0_1003                67               0           116.0             58.0
# 8  0_10033                55               1           110.0            110.0
# 9  0_10038                40               1            69.0             69.0
#
#    item_cnt_day_sum  item_cnt_day_mean  target
# 0               5.0                1.0     4.0
# 1               4.0                1.0     NaN
# 2               1.0                1.0     NaN
# 3               2.0                1.0     NaN
# 4               1.0                1.0     2.0
# 5               2.0                1.0     NaN
# 6               2.0                1.0     NaN
# 7               2.0                1.0     NaN
# 8               1.0                1.0     NaN
# 9               1.0                1.0     NaN

# %%
sales_agg_features_target_train_test = sales_agg_features_target[~sales_agg_features_target['target'].isnull()]

# %%
sales_train = sales_agg_features_target_train_test[~sales_agg_features_target_train_test['date_block_num'].isin([25,26,27,28,29,30,31,32,33])]
sales_test = sales_agg_features_target_train_test[sales_agg_features_target_train_test['date_block_num'].isin([25,26,27,28,29,30,31,32,33])]
print(sales_test.shape[0]/sales_agg_features_target_train_test.shape[0], sales_train.shape[0]/sales_agg_features_target_train_test.shape[0])
# Out:
# 0.16834284464593388 0.8316571553540661

# %%
sales_train['item_category_id'] = sales_train['item_category_id'].astype('category')
sales_test['item_category_id'] = sales_test['item_category_id'].astype('category')
sales_train['date_block_num'] = sales_train['date_block_num'].astype('category')
sales_test['date_block_num'] = sales_test['date_block_num'].astype('category')
# Out:
# /tmp/ipykernel_26585/1316856615.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_train['item_category_id'] = sales_train['item_category_id'].astype('category')
# /tmp/ipykernel_26585/1316856615.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_test['item_category_id'] = sales_test['item_category_id'].astype('category')
# /tmp/ipykernel_26585/1316856615.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_train['date_block_num'] = sales_train['date_block_num'].astype('category')
# /tmp/ipykernel_26585/1316856615.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_test['date_block_num'] = sales_test['date_block_num'].astype('category')

# %%
sales_test.dtypes
# Out:
# ID                     object
# item_category_id     category
# date_block_num       category
# item_price_sum        float64
# item_price_mean       float64
# item_cnt_day_sum      float64
# item_cnt_day_mean     float64
# target                float64
# dtype: object

# %%
X_train = sales_train.drop(['ID','target'],axis=1)
y_train = sales_train['target']

X_test = sales_test.drop(['ID','target'],axis=1)
y_test = sales_test['target']

# %%
model = RandomForestRegressor(n_estimators=100,criterion='squared_error',random_state=42)
model_rf = model.fit(X_train, y_train)

# %%
predicted_train=model_rf.predict(X_train)
predicted_test=model_rf.predict(X_test)

print(f'OOF score: {sqrt(mean_squared_error(y_train, predicted_train))}')
print(f'HOLDOUT score: {sqrt(mean_squared_error(y_test, predicted_test))}')
# Out:
# OOF score: 2.6872724536725805
# HOLDOUT score: 12.040495373656215

# %% [markdown]
# ## Hyperparams tuning by Optuna

# %%
def objective(trial):
    '''
    The function initialize search space hyperparams, train model, predict values, evaluate by metrics.

            Parameters:
                    trial (object of Optuna class)
        
            Returns:
                    RMSE (int): evaluate model by RMSE
    '''
    criterion = trial.suggest_categorical('criterion', ['mse'])
    bootstrap = trial.suggest_categorical('bootstrap',['True','False'])
    max_depth = trial.suggest_int('max_depth', 10, 100)
    max_features = trial.suggest_categorical('max_features', ['auto', 'sqrt','log2'])
    max_leaf_nodes = trial.suggest_int('max_leaf_nodes', 10, 100)
    n_estimators =  trial.suggest_int('n_estimators', 30, 300)
    
    regr = RandomForestRegressor(bootstrap = bootstrap, criterion = criterion,
                                 max_depth = max_depth, max_features = max_features,
                                 max_leaf_nodes = max_leaf_nodes,n_estimators = n_estimators,n_jobs=-1)
    
    
    regr.fit(X_train, y_train)
    predicted_test = regr.predict(X_test)

    return sqrt(mean_squared_error(y_test, predicted_test))

# %%
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=100)

#Create an instance with tuned hyperparameters
optimised_rf = RandomForestRegressor(bootstrap = study.best_params['bootstrap'], criterion = study.best_params['criterion'],
                                     max_depth = study.best_params['max_depth'], max_features = study.best_params['max_features'],
                                     max_leaf_nodes = study.best_params['max_leaf_nodes'],n_estimators = study.best_params['n_estimators'],
                                     n_jobs=12)
#learn
optimised_rf.fit(X_train ,y_train)

predicted_train=optimised_rf.predict(X_train)
predicted_test=optimised_rf.predict(X_test)

print(f'OOF score: {sqrt(mean_squared_error(y_train, predicted_train))}')
print(f'HOLDOUT score: {sqrt(mean_squared_error(y_test, predicted_test))}')
# Out:
# [I 2023-12-26 05:21:06,324] A new study created in memory with name: no-name-bed403e3-8e3a-49b7-8f42-ae7b2548d819
# /home/namenode/.local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# [I 2023-12-26 05:21:13,678] Trial 0 finished with value: 11.79742959262202 and parameters: {'criterion': 'mse', 'bootstrap': 'False', 'max_depth': 58, 'max_features': 'sqrt', 'max_leaf_nodes': 75, 'n_estimators': 218}. Best is trial 0 with value: 11.79742959262202.
# /home/namenode/.local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /home/namenode/.local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-12-26 05:21:17,370] Trial 1 finished with value: 11.874561650807804 and parameters: {'criterion': 'mse', 'bootstrap': 'False', 'max_depth': 18, 'max_features': 'auto', 'max_leaf_nodes': 21, 'n_estimators': 54}. Best is trial 0 with value: 11.79742959262202.
# /home/namenode/.local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# [I 2023-12-26 05
and parameters: {'criterion': 'mse', 'bootstrap': 'True', 'max_depth': 22, 'max_features': 'sqrt', 'max_leaf_nodes': 95, 'n_estimators': 82}. Best is trial 62 with value: 11.508320835785065.
# /home/namenode/.local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# [I 2023-12-26 05:27:41,250] Trial 81 finished with value: 11.597617750574459 and parameters: {'criterion': 'mse', 'bootstrap': 'True', 'max_depth': 16, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'n_estimators': 31}. Best is trial 62 with value: 11.508320835785065.
# /home/namenode/.local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# [I 2023-12-26 05:27:43,022] Trial 82 finished with value: 11.685694117534693 and parameters: {'criterion': 'mse', 'bootstrap': 'True', 'max_depth': 17, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'n_estimators': 40}. Best is trial 62 with value: 11.508320835785065.
# /home/namenode/.local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# [I 2023-12-26 05:27:45,325] Trial 83 finished with value: 11.777891082512632 and parameters: {'criterion': 'mse', 'bootstrap': 'True', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 96, 'n_estimators': 57}. Best is trial 62 with value: 11.508320835785065.
# /home/namenode/.local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# [I 2023-12-26 05:27:46,776] Trial 84 finished with value: 11.885534902417824 and parameters: {'criterion': 'mse', 'bootstrap': 'True', 'max_depth': 19, 'max_features': 'sqrt', 'max_leaf_nodes': 89, 'n_estimators': 30}. Best is trial 62 with value: 11.508320835785065.
# /home/namenode/.local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# [I 2023-12-26 05:27:49,398] Trial 85 finished with value: 11.650316413045385 and parameters: {'criterion': 'mse', 'bootstrap': 'True', 'max_depth': 14, 'max_features': 'sqrt', 'max_leaf_nodes': 95, 'n_estimators': 69}. Best is trial 62 with value: 11.508320835785065.
# /home/namenode/.local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# [I 2023-12-26 05:27:52,781] Trial 86 finished with value: 11.827582735278128 and parameters: {'criterion': 'mse', 'bootstrap': 'True', 'max_depth': 15, 'max_features': 'sqrt', 'max_leaf_nodes': 92, 'n_estimators': 94}. Best is trial 62 with value: 11.508320835785065.
# /home/namenode/.local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# [I 2023-12-26 05:27:55,556] Trial 87 finished with value: 11.741288396142455 and parameters: {'criterion': 'mse', 'bootstrap': 'True', 'max_depth': 13, 'max_features': 'sqrt', 'max_leaf_nodes': 95, 'n_estimators': 70}. Best is trial 62 with value: 11.508320835785065.
# /home/namenode/.local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# [I 2023-12-26 05:27:57,655] Trial 88 finished with value: 11.71214014243461 and parameters: {'criterion': 'mse', 'bootstrap': 'True', 'max_depth': 89, 'max_features': 'sqrt', 'max_leaf_nodes': 98, 'n_estimators': 50}. Best is trial 62 with value: 11.508320835785065.
# /home/namenode/.local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# [I 2023-12-26 05:28:01,518] Trial 89 finished with value: 11.834363751665423 and parameters: {'criterion': 'mse', 'bootstrap': 'True', 'max_depth': 17, 'max_features': 'sqrt', 'max_leaf_nodes': 92, 'n_estimators': 104}. Best is trial 62 with value: 11.508320835785065.
# /home/namenode/.local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# [I 2023-12-26 05:28:03,910] Trial 90 finished with value: 11.82184538083127 and parameters: {'criterion': 'mse', 'bootstrap': 'True', 'max_depth': 20, 'max_features': 'sqrt', 'max_leaf_nodes': 86, 'n_estimators': 58}. Best is trial 62 with value: 11.508320835785065.
# /home/namenode/.local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# [I 2023-12-26 05:28:05,778] Trial 91 finished with value: 11.805953791540135 and parameters: {'criterion': 'mse', 'bootstrap': 'True', 'max_depth': 28, 'max_features': 'sqrt', 'max_leaf_nodes': 98, 'n_estimators': 37}. Best is trial 62 with value: 11.508320835785065.
# /home/namenode/.local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /home/namenode/.local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-12-26 05:28:11,341] Trial 92 finished with value: 12.225130663992601 and parameters: {'criterion': 'mse', 'bootstrap': 'True', 'max_depth': 14, 'max_features': 'auto', 'max_leaf_nodes': 94, 'n_estimators': 71}. Best is trial 62 with value: 11.508320835785065.
# /home/namenode/.local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# [I 2023-12-26 05:28:13,298] Trial 93 finished with value: 11.720688437210281 and parameters: {'criterion': 'mse', 'bootstrap': 'True', 'max_depth': 45, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'n_estimators': 45}. Best is trial 62 with value: 11.508320835785065.
# /home/namenode/.local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# [I 2023-12-26 05:28:16,350] Trial 94 finished with value: 12.035690794855572 and parameters: {'criterion': 'mse', 'bootstrap': 'True', 'max_depth': 38, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'n_estimators': 118}. Best is trial 62 with value: 11.508320835785065.
# /home/namenode/.local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# [I 2023-12-26 05:28:18,082] Trial 95 finished with value: 11.619759680879541 and parameters: {'criterion': 'mse', 'bootstrap': 'True', 'max_depth': 26, 'max_features': 'sqrt', 'max_leaf_nodes': 90, 'n_estimators': 37}. Best is trial 62 with value: 11.508320835785065.
# /home/namenode/.local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# [I 2023-12-26 05:28:19,750] Trial 96 finished with value: 11.876561986158988 and parameters: {'criterion': 'mse', 'bootstrap': 'True', 'max_depth': 23, 'max_features': 'sqrt', 'max_leaf_nodes': 90, 'n_estimators': 37}. Best is trial 62 with value: 11.508320835785065.
# /home/namenode/.local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# [I 2023-12-26 05:28:22,210] Trial 97 finished with value: 11.81438606559767 and parameters: {'criterion': 'mse', 'bootstrap': 'True', 'max_depth': 25, 'max_features': 'sqrt', 'max_leaf_nodes': 96, 'n_estimators': 62}. Best is trial 62 with value: 11.508320835785065.
# /home/namenode/.local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# [I 2023-12-26 05:28:24,305] Trial 98 finished with value: 11.753271601700469 and parameters: {'criterion': 'mse', 'bootstrap': 'True', 'max_depth': 55, 'max_features': 'sqrt', 'max_leaf_nodes': 93, 'n_estimators': 52}. Best is trial 62 with value: 11.508320835785065.
# /home/namenode/.local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# [I 2023-12-26 05:28:25,717] Trial 99 finished with value: 11.758452730463244 and parameters: {'criterion': 'mse', 'bootstrap': 'True', 'max_depth': 11, 'max_features': 'sqrt', 'max_leaf_nodes': 95, 'n_estimators': 30}. Best is trial 62 with value: 11.508320835785065.
# /home/namenode/.local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# OOF score: 4.606263868678547
# HOLDOUT score: 11.625470394937363

# %%
optimised_rf
# Out:
# RandomForestRegressor(bootstrap='True', criterion='mse', max_depth=14,
#                       max_features='sqrt', max_leaf_nodes=98, n_estimators=30,
#                       n_jobs=12)

# %%
joblib.dump(optimised_rf,'optimised_rf.pkl')
# Out:
# ['optimised_rf.pkl']
